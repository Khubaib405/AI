# %% [markdown]
# **import lib**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# **Read file**

# %%
data = pd.read_csv("train.csv")

# %% [markdown]
# **Display data**

# %%
data
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  3.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Date of Joining       22750 non-null  object
#  2   Gender                22750 non-null  object
#  3   Company Type          22750 non-null  object
#  4   WFH Setup Available   22750 non-null  object
#  5   Designation           22750 non-null  float64
#  6   Resource Allocation   21369 non-null  float64
#  7   Mental Fatigue Score  20633 non-null  float64
#  8   Burn Rate             21626 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# **explain TArget and feature**

# %%
X = data.drop(['Designation', 'Resource Allocation', 'Mental Fatigue Score'], axis=1)
y = data['Burn Rate']
X, y
# Out:
# (                    Employee ID Date of Joining  Gender Company Type  \
#  0      fffe32003000360033003200      2008-09-30  Female      Service
#  1          fffe3700360033003500      2008-11-30    Male      Service
#  2      fffe31003300320037003900      2008-03-10  Female      Product
#  3      fffe32003400380032003900      2008-11-03    Male      Service
#  4      fffe31003900340031003600      2008-07-24  Female      Service
#  ...                         ...             ...     ...          ...
#  22745  fffe31003500370039003100      2008-12-30  Female      Service
#  22746  fffe33003000350031003800      2008-01-19  Female      Product
#  22747          fffe390032003000      2008-11-05    Male      Service
#  22748  fffe33003300320036003900      2008-01-10  Female      Service
#  22749      fffe3400350031003800      2008-01-06    Male      Product
#
#        WFH Setup Available  Burn Rate
#  0                      No       0.16
#  1                     Yes       0.36
# ...

# %% [markdown]
# **Train**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# **Linear Regre....**

# %%
from sklearn.linear_model import LinearRegression

# Load the data into a pandas DataFrame
data = pd.read_csv('train.csv')

# Remove any rows with missing values
data.dropna(inplace=True)

# Convert the X and y variables to numeric values
X = data[['Designation', 'Resource Allocation', 'Mental Fatigue Score']].astype(float)
y = data['Burn Rate'].astype(float)

# Fit the Linear Regression model
model = LinearRegression()
model.fit(X, y)

print(model.coef_)
print(model.intercept_)
# Out:
# [-0.00524831  0.02941739  0.07438628]
# -0.09449518321764239

# %% [markdown]
# **RMSE**

# %%
from sklearn.metrics import mean_squared_error
y_pred = model.predict(X)

rmse = mean_squared_error(y, y_pred, squared=False)
print(rmse)
# Out:
# 0.056046017035067716

# %% [markdown]
# **Graph**

# %%
import matplotlib.pyplot as plt

plt.scatter(data['Designation'], data['Burn Rate'], color='red')
plt.scatter(data['Resource Allocation'], data['Burn Rate'], color='green')
plt.scatter(data['Mental Fatigue Score'], data['Burn Rate'], color='blue')
plt.show()
